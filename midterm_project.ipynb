# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
netflix= pd.read_csv("netflix_daily_top_10.csv")

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
#  10  Point                 7100 non-null   int64
#  11  Month                 7100 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 665.8+ KB

# %%
netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# ...

# %%
ratings_tsv="title.ratings.tsv"
 
# reading given tsv file
ratings_csv=pd.read_table(ratings_tsv, sep='\t')
 
# converting tsv file into csv
ratings_csv.to_csv('title.ratings.csv', index=False)
 
# output
print("Successfully made csv file")
# Out:
# Successfully made csv file

# %%
ratings= pd.read_csv("title.ratings.csv")

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1948
# 1        tt0000002            5.8       264
# 2        tt0000003            6.5      1778
# 3        tt0000004            5.6       179
# 4        tt0000005            6.2      2582
# ...            ...            ...       ...
# 1275127  tt9916730            8.1         9
# 1275128  tt9916766            7.0        21
# 1275129  tt9916778            7.2        36
# 1275130  tt9916840            8.8         6
# 1275131  tt9916880            8.2         6
#
# [1275132 rows x 3 columns]

# %%
titles_tsv= "title.basics.tsv"

# reading given tsv file
titles_csv=pd.read_table(titles_tsv, sep='\t')
 
# converting tsv file into csv
titles_csv.to_csv("title.basics.csv", index=False)
 
# output
print("Successfully made csv file")
# Out:
# /var/folders/t4/m86mwfns0ll4fvy0p6jmyhyr0000gp/T/ipykernel_17873/371064780.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   titles_csv=pd.read_table(titles_tsv, sep='\t')
# Successfully made csv file

# %%
titles= pd.read_csv("title.basics.csv")
# Out:
# /var/folders/t4/m86mwfns0ll4fvy0p6jmyhyr0000gp/T/ipykernel_17873/3572036888.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   titles= pd.read_csv("title.basics.csv")

# %%
titles.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
names_tsv="name.basics.tsv"
 
# reading given tsv file
names_csv=pd.read_table(names_tsv, sep='\t')
 
# converting tsv file into csv
names_csv.to_csv('name.basics.csv', index=False)
 
# output
print("Successfully made csv file")
# Out:
# Successfully made csv file

# %%
names= pd.read_csv("name.basics.csv")

# %%
names
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12278048  nm9993714   Romeo del Rosario        \N        \N
# 12278049  nm9993716       Essias Loberg        \N        \N
# 12278050  nm9993717  Harikrishnan Rajan        \N        \N
# 12278051  nm9993718         Aayush Nair        \N        \N
# 12278052  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
films= names['knownForTitles'].str.split(',', expand = True)

# %%
#horizontal_concat_df = pd.concat([df1,df2,df3], axis=1)

# %%
names= pd.concat([names, films], axis=1)

# %%
names.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles          0          1          2  \
# 0  tt0053137,tt0072308,tt0050419,tt0045537  tt0053137  tt0072308  tt0050419
# 1  tt0038355,tt0071877,tt0037382,tt0117057  tt0038355  tt0071877  tt0037382
# 2  tt0057345,tt0056404,tt0054452,tt0049189  tt0057345  tt0056404  tt0054452
# 3  tt0072562,tt0077975,tt0078723,tt0080455  tt0072562  tt0077975  tt0078723
# ...

# %%
netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# ...

# %%
netflix
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %%
Point=[]
for i in range (7100):
    Point.append(10-(i%10))g

# %%
netflix["Point"]=Point

# %%
netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score  Point
# 0         Mar 20, 2020               9                90     10
# 1         Jul 21, 2017               5                45      9
# 2         Mar 28, 2019               9                76      8
# ...

# %%
netflix.tail()
# Out:
#            As of  Rank Year to Date Rank Last Week Rank                Title  \
# 7095  2022-03-11     6                 5              1  Worst Roommate Ever
# 7096  2022-03-11     7                 7              2    Vikings: Valhalla
# 7097  2022-03-11     8                 8              -              Shooter
# 7098  2022-03-11     9                 9              7              Shrek 2
# 7099  2022-03-11    10                10              -                Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# 7095  TV Show               Yes          Mar 1, 2022              10
# 7096  TV Show               Yes         Feb 25, 2022              14
# 7097    Movie               NaN          Aug 1, 2014               3
# 7098    Movie               NaN          Mar 1, 2022              10
# 7099    Movie               NaN          May 1, 2018               7
#
#       Viewership Score  Point
# 7095                81      5
# ...

# %%
#netflix.to_excel(r'netflix.xlsx', index = False)

# %%
#netflix["Month"]=netflix["As of"][:4]

# %%
netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score  Point       Month
# 0         Mar 20, 2020               9                90     10  2020-04-01
# 1         Jul 21, 2017               5                45      9  2020-04-01
# ...

# %% [markdown]
# ## ALL TIME

# %%
goat= netflix.groupby(["Title"]).sum("Point")

# %%
goat
# Out:
#                             Rank  Days In Top 10  Viewership Score  Point
# Title
# #Alive                        32              21               134     34
# #blackAF                      53              36               183     35
# (Un)Well                      42              21                84     24
# 13 Reasons Why                80             253              2224    162
# 17 Again                      44              28               132     33
# ...                          ...             ...               ...    ...
# Your Highness                  9               1                 2      2
# Zookeeper                     24               6                16      9
# iCarly                       218             903              6207    244
# jeen-yuhs: A Kanye Trilogy    74              78               445     58
# Ãlite                        49              28               122     28
#
# [645 rows x 4 columns]

# %%
goat_sorted= goat.sort_values(['Point'], ascending=[False])

# %%
goat_sorted.head(10)
# Out:
#                       Rank  Days In Top 10  Viewership Score  Point
# Title
# Cocomelon             3234           91806            310352   1474
# Manifest               290            3240             27342    590
# Cobra Kai              309            3321             25088    582
# Outer Banks            258            2628             20303    534
# Ozark                  435            3995             25890    500
# Squid Game             231            2211             19595    495
# The Queenâs Gambit   357            2701             20701    446
# Bridgerton             206            1711             14946    432
# Lucifer                211            1631             12372    405
# Virgin River           214            1540             11315    391

# %%
goat_sorted.to_excel(r'best_of_all.xlsx', index = False)

# %% [markdown]
# ## LONGEST No.1

# %%
#Longest=[]
#for i in range (71):
#         Longest.append(netflix.iloc[:i*10])

# %%
#Longest

# %%
longest=netflix[(netflix['Rank']==1)]

# %%
longest=longest[["Rank", "Title"]]

# %%
longest.value_counts()
# Out:
# Rank  Title
# 1     Cobra Kai          27
#       Squid Game         23
#       Virgin River       20
#       Manifest           19
#       Outer Banks        19
#                          ..
#       Hillbilly Elegy     1
#       Good Girls          1
#       The Willoughbys     1
#       The Upshaws         1
#       Love is Blind       1
# Length: 123, dtype: int64

# %%
longest.to_excel(r'longest.xlsx', index = False)

# %%
netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score  Point    Month
# 0         Mar 20, 2020               9                90     10  2020-04
# 1         Jul 21, 2017               5                45      9  2020-04
# ...

# %%
netflix.to_excel(r'netflix.xlsx', index = False)

# %%
a=netflix.groupby(["Month", "Title"]).sum("Point")

# %%
a
# Out:
#                                         Rank  Days In Top 10  \
# Month   Title
# 2020-04 #blackAF                          53              36
#         Absurd Planet                     35              10
#         All American                     125             370
#         Angel Has Fallen                  70              78
#         Badland                            9               4
# ...                                      ...             ...
# 2022-03 The Weekend Away                  38              21
#         Tyler Perryâs A Madea Homec…    47              60
#         Vikings: Valhalla                 47              99
#         Worst Roommate Ever               29              55
#         jeen-yuhs: A Kanye Trilogy        33              42
#
#                                         Viewership Score  Point
# Month   Title
# 2020-04 #blackAF                                     183     35
#         Absurd Planet                                 21      9
# ...

# %%
b=a.sort_values(['Month', 'Point'], ascending=[True, False])

# %%
b
# Out:
#                                       Rank  Days In Top 10  Viewership Score  \
# Month   Title
# 2020-04 Tiger King: Murder, Mayhem …    76             594              5725
#         Ozark                          124             585              4839
#         Outer Banks                     42             120               949
#         All American                   125             370              2535
#         Too Hot to Handle               57              91               717
# ...                                    ...             ...               ...
# 2022-03 Battleship                      27               6                15
#         Against the Ice                 18               3                 6
#         Ozark                            7              89               536
#         Despicable Me 2                  8              27                88
#         Cocomelon                        9             428              1474
#
# ...

# %%
#for i in range (b["Month"].unique()):

# %%
b
# Out:
#                                       Rank  Days In Top 10  Viewership Score  \
# Month   Title
# 2020-04 Tiger King: Murder, Mayhem …    76             594              5725
#         Ozark                          124             585              4839
#         Outer Banks                     42             120               949
#         All American                   125             370              2535
#         Too Hot to Handle               57              91               717
# ...                                    ...             ...               ...
# 2022-03 Battleship                      27               6                15
#         Against the Ice                 18               3                 6
#         Ozark                            7              89               536
#         Despicable Me 2                  8              27                88
#         Cocomelon                        9             428              1474
#
# ...

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b.index
# Out:
# MultiIndex([('2020-04', 'Tiger King: Murder, Mayhem …'),
#             ('2020-04',                        'Ozark'),
#             ('2020-04',                  'Outer Banks'),
#             ('2020-04',                 'All American'),
#             ('2020-04',            'Too Hot to Handle'),
#             ('2020-04',                  'Money Heist'),
#             ('2020-04',                'Despicable Me'),
#             ('2020-04',                         'Waco'),
#             ('2020-04',             'Angel Has Fallen'),
#             ('2020-04',                   'Extraction'),
#             ...
#             ('2022-03',   'jeen-yuhs: A Kanye Trilogy'),
#             ('2022-03',             'Just Like Heaven'),
#             ('2022-03',                     'Restless'),
#             ('2022-03',                      'Shooter'),
#             ('2022-03',              'Sweet Magnolias'),
#             ('2022-03',                   'Battleship'),
# ...

# %%
b.columns
# Out:
# Index(['Rank', 'Days In Top 10', 'Viewership Score', 'Point'], dtype='object')

# %%
b.index
# Out:
# MultiIndex([('2020-04', 'Tiger King: Murder, Mayhem …'),
#             ('2020-04',                        'Ozark'),
#             ('2020-04',                  'Outer Banks'),
#             ('2020-04',                 'All American'),
#             ('2020-04',            'Too Hot to Handle'),
#             ('2020-04',                  'Money Heist'),
#             ('2020-04',                'Despicable Me'),
#             ('2020-04',                         'Waco'),
#             ('2020-04',             'Angel Has Fallen'),
#             ('2020-04',                   'Extraction'),
#             ...
#             ('2022-03',   'jeen-yuhs: A Kanye Trilogy'),
#             ('2022-03',             'Just Like Heaven'),
#             ('2022-03',                     'Restless'),
#             ('2022-03',                      'Shooter'),
#             ('2022-03',              'Sweet Magnolias'),
#             ('2022-03',                   'Battleship'),
# ...

# %%
b.loc['2020-04']
# Out:
#                               Rank  Days In Top 10  Viewership Score  Point
# Title
# Tiger King: Murder, Mayhem …    76             594              5725    221
# Ozark                          124             585              4839    206
# Outer Banks                     42             120               949    123
# All American                   125             370              2535     95
# Too Hot to Handle               57              91               717     86
# Money Heist                     96             136               795     80
# Despicable Me                   37              55               477     73
# Waco                            65              78               435     67
# Angel Has Fallen                70              78               450     62
# Extraction                       7              21               209     59
# The Willoughbys                 30              36               283     58
# ...

# %%
b.loc['2020-04'][:9]
# Out:
#                               Rank  Days In Top 10  Viewership Score  Point
# Title
# Tiger King: Murder, Mayhem …    76             594              5725    221
# Ozark                          124             585              4839    206
# Outer Banks                     42             120               949    123
# All American                   125             370              2535     95
# Too Hot to Handle               57              91               717     86
# Money Heist                     96             136               795     80
# Despicable Me                   37              55               477     73
# Waco                            65              78               435     67
# Angel Has Fallen                70              78               450     62

# %%
netflix["Month"].unique()
# Out:
# array(['2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09',
#        '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03',
#        '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09',
#        '2021-10', '2021-11', '2021-12', '2022-01', '2022-02', '2022-03'],
#       dtype=object)

# %%
netflix["Month"].unique()[0]
# Out:
# '2020-04'

# %%
netflix["Month"].unique()
# Out:
# array(['2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09',
#        '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03',
#        '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09',
#        '2021-10', '2021-11', '2021-12', '2022-01', '2022-02', '2022-03'],
#       dtype=object)

# %%
netflix["Month"].unique()[0]
# Out:
# '2020-04'

# %%
monthly=pd.DataFrame()

# %%
#(columns=b.columns)
for i in range (len(netflix["Month"].unique())):
    x=netflix["Month"].unique()[i]
    z=b.loc[x][:10]
    #print(type(z))
    #print(z)
    #monthly.append(z)
    monthly = pd.concat(index)
    monthly = pd.concat([monthly, z], axis=0)
# Out:
#                               Rank  Days In Top 10  Viewership Score  Point
# Title
# Tiger King: Murder, Mayhem …    76             594              5725    221
# Ozark                          124             585              4839    206
# Outer Banks                     42             120               949    123
# All American                   125             370              2535     95
# Too Hot to Handle               57              91               717     86
# Money Heist                     96             136               795     80
# Despicable Me                   37              55               477     73
# Waco                            65              78               435     67
# Angel Has Fallen                70              78               450     62
# Extraction                       7              21               209     59
#                             Rank  Days In Top 10  Viewership Score  Point
# Title
# ...

# %%
monthly
# Out:
#                                 Rank  Days In Top 10  Viewership Score  Point
# Title
# Tiger King: Murder, Mayhem …      76             594              5725    221
# Ozark                            124             585              4839    206
# Outer Banks                       42             120               949    123
# All American                     125             370              2535     95
# Too Hot to Handle                 57              91               717     86
# ...                              ...             ...               ...    ...
# Tyler Perryâs A Madea Homec…    47              60               454     41
# Shrek 2                           77              55               202     33
# Good Girls                        13              98               547     31
# The Weekend Away                  38              21               112     28
# The Last Kingdom                   3              25               114     19
#
# [240 rows x 4 columns]

# %%
monthly.index
# Out:
# Index(['Tiger King: Murder, Mayhem …', 'Ozark', 'Outer Banks', 'All American',
#        'Too Hot to Handle', 'Money Heist', 'Despicable Me', 'Waco',
#        'Angel Has Fallen', 'Extraction',
#        ...
#        'Inventing Anna', 'Worst Roommate Ever', 'Vikings: Valhalla',
#        'Love is Blind', 'Pieces of Her', 'Tyler Perryâs A Madea Homec…',
#        'Shrek 2', 'Good Girls', 'The Weekend Away', 'The Last Kingdom'],
#       dtype='object', name='Title', length=240)

# %%
Title=[]
for i in range (len(monthly["Point"])):
         Title.append(monthly.index[i])

monthly["Title"]=Title

# %%
monthly
# Out:
#                                 Rank  Days In Top 10  Viewership Score  Point  \
# Title
# Tiger King: Murder, Mayhem …      76             594              5725    221
# Ozark                            124             585              4839    206
# Outer Banks                       42             120               949    123
# All American                     125             370              2535     95
# Too Hot to Handle                 57              91               717     86
# ...                              ...             ...               ...    ...
# Tyler Perryâs A Madea Homec…    47              60               454     41
# Shrek 2                           77              55               202     33
# Good Girls                        13              98               547     31
# The Weekend Away                  38              21               112     28
# The Last Kingdom                   3              25               114     19
#
# ...

# %%
len(monthly["Point"])
# Out:
# 240

# %%
Month=[]
for i in range (240):
    Month.append(netflix["Month"].unique()[math.floor(i/10)])

monthly["Month"]=Month

# %%
Number_of_Month=[]
for i in range (1,241):
    Number_of_Month.append(math.ceil(i/10))

monthly["Number of Month"]= Number_of_Month

# %%
monthly.tail(11)
# Out:
#                                 Rank  Days In Top 10  Viewership Score  Point  \
# Title
# jeen-yuhs: A Kanye Trilogy        41              36               230     47
# Inventing Anna                    35             253              2331     86
# Worst Roommate Ever               29              55               485     81
# Vikings: Valhalla                 47              99               804     74
# Love is Blind                     48             451              3075     73
# Pieces of Her                      9              28               272     68
# Tyler Perryâs A Madea Homec…    47              60               454     41
# Shrek 2                           77              55               202     33
# Good Girls                        13              98               547     31
# The Weekend Away                  38              21               112     28
# The Last Kingdom                   3              25               114     19
#
# ...

# %%
monthly.to_excel(r'monthly.xlsx', index = False)

# %%
len(monthly["Title"].unique())
# Out:
# 186

# %%
netflix["Netflix Exclusive"].count
# Out:
# <bound method Series.count of 0       Yes
# 1       Yes
# 2       NaN
# 3       NaN
# 4       Yes
#        ...
# 7095    Yes
# 7096    Yes
# 7097    NaN
# 7098    NaN
# 7099    NaN
# Name: Netflix Exclusive, Length: 7100, dtype: object>

# %%
netflix.groupby(by="Netflix Exclusive").count()
# Out:
#                    As of  Rank  Year to Date Rank  Last Week Rank  Title  \
# Netflix Exclusive
# Yes                 4599  4599               4599            4599   4599
#
#                    Type  Netflix Release Date  Days In Top 10  \
# Netflix Exclusive
# Yes                4599                  4599            4599
#
#                    Viewership Score  Point  Month
# Netflix Exclusive
# Yes                            4599   4599   4599

# %%
netflix["Netflix Exclusive"].unique()
# Out:
# array(['Yes', nan], dtype=object)

# %%
netflix["Netflix Exclusive"].isna().sum()
# Out:
# 2501
